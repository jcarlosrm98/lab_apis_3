# %% [markdown]
# ![spotify_logo](../img/spotify_logo.png)
#
# # Spotify REST API Challenge
#
# __What to listen?__
#
# Create your own playlist based on the related artists and their most popular tracks using the [Spotify REST API](https://developer.spotify.com/)

# %%
# Imports
import requests as req
import pandas as pd

# %% [markdown]
# ### Get access!!!
#
# Get your `client_id` and `client_secret` to generate your __token__ access

# %%
# Generate token with a POST request

client_id = "d57aebdd41374dd0a03d37edd6ae1c5e"
client_secret = "a5b9dc1af28f43e6ac633332f0bde172"
auth_url = 'https://accounts.spotify.com/api/token'

# %%
auth_response = req.post(auth_url, {'grant_type': 'client_credentials',
                                         'client_id': client_id,
                                         'client_secret': client_secret}).json()

# %%
access_token = auth_response['access_token']
auth_response
# Out:
# {'access_token': 'BQDXs1hpX4mlNMTqmYooYpyg68sHQMKYQ3RzVRc7TaBrNt00sTQx21x3dIuNKrqB8dxqV7KTvV7QWYXWJffhqDtnh-uMcL6U62Q7NuSU0_k3W5wMRKA',
#  'token_type': 'Bearer',
#  'expires_in': 3600}

# %% [markdown]
# ### Set your main variables!!!
#
# Set the `base_uri` (i.e.: end-point), parameters and `headers` for your __GET__ operations

# %%
# Base end-point construction

base_url = 'https://api.spotify.com/v1/'
resource = 'artists/'

header_info = {'Authorization': 'Bearer {token}'.format(token=access_token)}

# %% [markdown]
# ### Create your new playlist!!!
#
# Use [`/related-artists`](https://developer.spotify.com/documentation/web-api/reference/#/operations/get-an-artists-related-artists) and [`/top-tracks`](https://developer.spotify.com/documentation/web-api/reference/#/operations/get-an-artists-top-tracks) in order to get the data that you need.
#
# __Here you have the different artists to start with:__
#
# - __Option 1:__ 0L8ExT028jH3ddEcZwqJJ5
#
# - __Option 2:__ 4Y7tXHSEejGu1vQ9bwDdXW
#
# - __Option 3:__ 6FBDaR13swtiWwGhX1WQsP
#
# - __Option 4:__ 0kyQwKHCZnKE7kTXkxXjrB
#
# - __Option 5:__ 2d0hyoQ5ynDBnkvAbJKORj
#
# - __Option 6:__ 3bgsNtcf5d5h9jbQbohfBK
#
# - __Option 7:__ 7mWCSSOYqm4E9mB7V4ot6S
#
# - __Option 8:__ 64KEffDW9EtZ1y2vBYgq8T
#
# - __Option 9:__ 4k1ELeJKT1ISyDv8JivPpB
#
# - __Option 10:__ 4Z8W4fKeB5YxbusRsdQVPb
#
# - __Option 11:__ 26dSoYclwsYLMAKD3tpOr4
#
# - __Option 12:__ 7y97mc3bZRFXzT2szRM4L4
#
# - __Option 13:__ 1w5Kfo2jwwIPruYS2UWh56
#
#
# > Remember to check the [Requests](https://requests.readthedocs.io/en/latest/) library docs!!!
#
# ---

# %%
# Here you can complete your endpoint URI

artist = '2Wwiu1wnq1W8AMYbWuRFDH'

full_endpoint = base_url + resource + artist

full_endpoint
# Out:
# 'https://api.spotify.com/v1/artists/2Wwiu1wnq1W8AMYbWuRFDH'

# %%
# Start building your playlist!!!
relres = req.get(full_endpoint + '/related-artists', headers=header_info)
related = relres.json()
df = pd.json_normalize(related['artists'])
df.explode('genres').head()
# Out:
#                      genres  \
# 0              murcia indie
# 0  rock alternativo espanol
# 0         spanish indie pop
# 0       spanish modern rock
# 1  rock alternativo espanol
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/artists/57s0ep3eNSg...  57s0ep3eNSg81D7ZxiuHbC
# 0  https://api.spotify.com/v1/artists/57s0ep3eNSg...  57s0ep3eNSg81D7ZxiuHbC
# 0  https://api.spotify.com/v1/artists/57s0ep3eNSg...  57s0ep3eNSg81D7ZxiuHbC
# 0  https://api.spotify.com/v1/artists/57s0ep3eNSg...  57s0ep3eNSg81D7ZxiuHbC
# 1  https://api.spotify.com/v1/artists/6rRTrEHzGSD...  6rRTrEHzGSDqhmFJQrNFMO
#
#                                               images         name  popularity  \
# 0  [{'height': 640, 'url': 'https://i.scdn.co/ima...  Viva Suecia          59
# 0  [{'height': 640, 'url': 'https://i.scdn.co/ima...  Viva Suecia          59
# 0  [{'height': 640, 'url': 'https://i.scdn.co/ima...  Viva Suecia          59
# 0  [{'height': 640, 'url': 'https://i.scdn.co/ima...  Viva Suecia          59
# 1  [{'height': 640, 'url': 'https://i.scdn.co/ima...      Shinova          52
#
#      type                                    uri  \
# 0  artist  spotify:artist:57s0ep3eNSg81D7ZxiuHbC
# 0  artist  spotify:artist:57s0ep3eNSg81D7ZxiuHbC
# 0  artist  spotify:artist:57s0ep3eNSg81D7ZxiuHbC
# 0  artist  spotify:artist:57s0ep3eNSg81D7ZxiuHbC
# 1  artist  spotify:artist:6rRTrEHzGSDqhmFJQrNFMO
#
#                                external_urls.spotify followers.href  \
# 0  https://open.spotify.com/artist/57s0ep3eNSg81D...           None
# 0  https://open.spotify.com/artist/57s0ep3eNSg81D...           None
# 0  https://open.spotify.com/artist/57s0ep3eNSg81D...           None
# 0  https://open.spotify.com/artist/57s0ep3eNSg81D...           None
# 1  https://open.spotify.com/artist/6rRTrEHzGSDqhm...           None
#
#    followers.total
# 0           142211
# 0           142211
# 0           142211
# 0           142211
# 1            71276

# %%
new_endpoint= 'https://api.spotify.com/v1/artists/'


argument= '?market=GB'


url = new_endpoint + artist + '/top-tracks' + argument

url
# Out:
# 'https://api.spotify.com/v1/artists/2Wwiu1wnq1W8AMYbWuRFDH/top-tracks?market=GB'

# %%
req.get(url, headers=header_info).json()['tracks'][0]
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2Wwiu1wnq1W8AMYbWuRFDH'},
#     'href': 'https://api.spotify.com/v1/artists/2Wwiu1wnq1W8AMYbWuRFDH',
#     'id': '2Wwiu1wnq1W8AMYbWuRFDH',
#     'name': 'Arde Bogotá',
#     'type': 'artist',
#     'uri': 'spotify:artist:2Wwiu1wnq1W8AMYbWuRFDH'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/0VgV2hz9fHoJBLKbqtj9cn'},
#   'href': 'https://api.spotify.com/v1/albums/0VgV2hz9fHoJBLKbqtj9cn',
#   'id': '0VgV2hz9fHoJBLKbqtj9cn',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273f877753076ae48397c1a789f',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02f877753076ae48397c1a789f',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851f877753076ae48397c1a789f',
#     'width': 64}],
#   'is_playable': True,
#   'name': 'COWBOYS DE LA A3',
#   'release_date': '2023-05-12',
#   'release_date_precision': 'day',
#   'total_tracks': 12,
#   'type': 'album',
#   'uri': 'spotify:album:0VgV2hz9fHoJBLKbqtj9cn'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2Wwiu1wnq1W8AMYbWuRFDH'},
#    'href': 'https://api.spotify.com/v1/artists/2Wwiu1wnq1W8AMYbWuRFDH',
#    'id': '2Wwiu1wnq1W8AMYbWuRFDH',
#    'name': 'Arde Bogotá',
#    'type': 'artist',
#    'uri': 'spotify:artist:2Wwiu1wnq1W8AMYbWuRFDH'}],
#  'disc_number': 1,
#  'duration_ms': 263942,
#  'explicit': False,
#  'external_ids': {'isrc': 'ES5022300053'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/0txzIz1WcoAn6m07xypcD5'},
#  'href': 'https://api.spotify.com/v1/tracks/0txzIz1WcoAn6m07xypcD5',
#  'id': '0txzIz1WcoAn6m07xypcD5',
#  'is_local': False,
#  'is_playable': True,
#  'name': 'La Salvación',
#  'popularity': 61,
#  'preview_url': 'https://p.scdn.co/mp3-preview/ce55601154016614d3094b16fe1d2d1e4ca02568?cid=d57aebdd41374dd0a03d37edd6ae1c5e',
#  'track_number': 12,
#  'type': 'track',
#  'uri': 'spotify:track:0txzIz1WcoAn6m07xypcD5'}

# %%
top_tracks = pd.concat([pd.DataFrame(req.get(new_endpoint + artista + '/top-tracks' + argument, 
                                                  headers=header_info).json()['tracks'])
                        for artista in df['id']])

# %%
top_tracks.head()
# Out:
#                                                album  \
# 0  {'album_type': 'album', 'artists': [{'external...
# 1  {'album_type': 'album', 'artists': [{'external...
# 2  {'album_type': 'album', 'artists': [{'external...
# 3  {'album_type': 'album', 'artists': [{'external...
# 4  {'album_type': 'single', 'artists': [{'externa...
#
#                                              artists  disc_number  \
# 0  [{'external_urls': {'spotify': 'https://open.s...            1
# 1  [{'external_urls': {'spotify': 'https://open.s...            1
# 2  [{'external_urls': {'spotify': 'https://open.s...            1
# 3  [{'external_urls': {'spotify': 'https://open.s...            1
# 4  [{'external_urls': {'spotify': 'https://open.s...            1
#
#    duration_ms  explicit              external_ids  \
# 0       206226     False  {'isrc': 'ES5702200992'}
# 1       159306     False  {'isrc': 'ES5702200993'}
# 2       180099     False  {'isrc': 'ES6061519101'}
# 3       181994     False  {'isrc': 'ESUM72302930'}
# 4       199551     False  {'isrc': 'ESUM72400367'}
#
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/track/6I...
# 1  {'spotify': 'https://open.spotify.com/track/6P...
# 2  {'spotify': 'https://open.spotify.com/track/0o...
# 3  {'spotify': 'https://open.spotify.com/track/3e...
# 4  {'spotify': 'https://open.spotify.com/track/3d...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/tracks/6IuZFiKCeyQI...  6IuZFiKCeyQINqL0Id3xF2
# 1  https://api.spotify.com/v1/tracks/6PLIfuZYh2Ir...  6PLIfuZYh2IrRNqJIEH26S
# 2  https://api.spotify.com/v1/tracks/0olbdwIJ3oSR...  0olbdwIJ3oSRERKdlmky4r
# 3  https://api.spotify.com/v1/tracks/3ewHmHFAtxQp...  3ewHmHFAtxQpRK8kGhnLeb
# 4  https://api.spotify.com/v1/tracks/3dFqQse30uPs...  3dFqQse30uPsmAWjw67dql
#
#    is_local  is_playable            name  popularity  \
# 0     False         True         El Bien          58
# 1     False         True  Hablar De Nada          57
# 2     False         True     Bien por Ti          55
# 3     False         True  Hablar De Nada          52
# 4     False         True       La Orilla          54
#
#                                          preview_url  track_number   type  \
# 0                                               None             1  track
# 1                                               None             5  track
# 2  https://p.scdn.co/mp3-preview/3281e635cb548231...             2  track
# 3                                               None            15  track
# 4                                               None             1  track
#
#                                     uri
# 0  spotify:track:6IuZFiKCeyQINqL0Id3xF2
# 1  spotify:track:6PLIfuZYh2IrRNqJIEH26S
# 2  spotify:track:0olbdwIJ3oSRERKdlmky4r
# 3  spotify:track:3ewHmHFAtxQpRK8kGhnLeb
# 4  spotify:track:3dFqQse30uPsmAWjw67dql

# %% [markdown]
# ---
#
# ### Bonus track!!!
#
# You can publish your own Playlist with [`/playlists`](https://developer.spotify.com/documentation/web-api/reference/#/operations/create-playlist) and [`/tracks`](https://developer.spotify.com/documentation/web-api/reference/#/operations/add-tracks-to-playlist).
#
# ![I quit](https://media.giphy.com/media/gui67fZ3xIneM/giphy.gif)

# %%
# Bonus

# %% [markdown]
# ---

# %% [markdown]
# You can always try with the [wrapper](https://github.com/plamere/spotipy)!!!
#
# ![I quit](https://media.giphy.com/media/3oFzlXPvXYZ4q8VQOs/giphy.gif)

# %% [markdown]
# ---
